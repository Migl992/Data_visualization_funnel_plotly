# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import csv

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ricca\Desktop\agid\txt.csv", sep='\t')

# %%
df.head()
# Out:
#                                    Column1
# 0   Benvenuto nella chat tree, Riccardo!!!
# 1                                 ðŸ¤šðŸ¤š
# 2                Ciao Riccardo, benvenuto
# 3                                 Welcome!
# 4           ðŸ‘‹ðŸ»ðŸ’ªðŸ»ðŸƒðŸ»â€â™‚

# %%
your_list = []
with open('txt.csv', 'rb') as f:
    reader = csv.reader(f)
    your_list = '\t'.join([i[0] for i in reader])
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-96-ec8b5485c2d2> in <module>
#       2 with open('txt.csv', 'rb') as f:
#       3     reader = csv.reader(f)
# ----> 4     your_list = '\t'.join([i[0] for i in reader])
#
# <ipython-input-96-ec8b5485c2d2> in <listcomp>(.0)
#       2 with open('txt.csv', 'rb') as f:
#       3     reader = csv.reader(f)
# ----> 4     your_list = '\t'.join([i[0] for i in reader])
#
# Error: iterator should return strings, not bytes (did you open the file in text mode?)

# %%
text = df["Column1"].values
wordcloud2 = WordCloud().generate('...'.join(text['Column1']))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-66c8cc5bdd9e> in <module>
#       1 text = df["Column1"].values
# ----> 2 wordcloud2 = WordCloud().generate('...'.join(text['Column1']))
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
